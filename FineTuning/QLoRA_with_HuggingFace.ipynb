# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # QLoRA with HuggingFace

# %% [markdown]
# QLoRA is an extension of LoRA that leverages quantization. Quantization is the process of mapping continuous infinite values to a smaller set of discrete finite values. Effectively, the model's parameters are are stored in 2, 3, 4 or 8-bits as opposed to the usual 32-bits, lowering the number of bits needed to store information. Quantization offers two benefits:
#
# 1. It reduced memory footprint. By using a finite set of discrete levels, the values can be represented with fewer bits, reducing the memory required to store them; and
# 2. It allows for efficient computation. Quantized values can be represented and processed more efficiently on hardware with limited numerical precision, such as low-power microcontrollers or specialized AI/ML accelerators.
#
# Choosing QLoRA over LoRA provides several tradeoffs. QLoRA offers the following advantages of LoRA:
#
# 1. Substantially smaller GPU memory usage than LoRA.
# 2. Higher maximum sequence lengths resulting from the smaller GPU memory usage.
# 3. Higher batch sizes resulting from the smaller GPU memory usage.
#
# The main disadvantage of QLoRA is slower fine-tuning speed.
#
# Interestingly enough, the accuracy of QLoRA and LoRA are comparable despite the fact that QLoRA offers substantially smaller models with lower GPU memory footprints than LoRA.
#
# The original QLoRA paper is available [here](https://arxiv.org/pdf/2305.14314).

# %% [markdown]
# **Note that the following uses the popular `BitsAndBytes` library to implement QLoRA, which only supports quantization using a CUDA-enabled GPU. You will not be able to run this notebook without a compatible GPU!**

# %% [markdown]
# # __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Install-required-libraries">Install required libraries</a></li>
#             <li><a href="#Import-required-libraries">Import required libraries</a></li>
#             <li><a href="#Define-helper-functions">Define helper functions</a></li>
#         </ol>
#     </li>
#     <li><a href="#IMDB-dataset">IMDB dataset</a></li>
#     <li><a href="#Tokenizer">Tokenizer</a></li>
#     <li><a href="#Configure-BitsAndBytes">Configure BitsAndBytes</a></li>
#     <li><a href="#Load-a-quantized-version-of-a-pretrained-model">Load a quantized version of a pretrained model</a></li>
#     <li><a href="#Train">Train</a></li>
#     <li><a href="#Results">Results</a></li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
# - Load and predict using models from HuggingFace
# - Fine-tune language models using QLoRA
# - Understand the advantages and disadvantages of QLoRA

# %% [markdown]
# ---

# %% [markdown]
# # Setup

# %% [markdown]
# ### Install required libraries
#
# For this lab, you use the following libraries, which are __not__ preinstalled in the Skills Network Labs environment. __You must run the code in the following cell__ to install them.

# %%
# !pip install torch==2.2.2
# !pip install torchtext==0.17.2
# !pip install portalocker==2.8.2
# !pip install torchdata==0.7.1
# !pip install pandas
# !pip install matplotlib==3.9.0 scikit-learn==1.5.0
# !pip install numpy==1.26.0
# !pip install huggingface_hub
# !pip install --user datasets
# !pip install transformers
# !pip install trl==0.11 peft==0.11.1 bitsandbytes==0.43.1
# Out:
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp310-none-macosx_11_0_arm64.whl (59.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 6.5 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2) (3.1.5)
# Requirement already satisfied: fsspec in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch==2.2.2) (2023.10.0)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch==2.2.2) (4.14.1)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2) (3.4.2)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2) (1.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from jinja2->torch==2.2.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from sympy->torch==2.2.2) (1.3.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0
#     Uninstalling torch-2.6.0:
#       Successfully uninstalled torch-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# Successfully installed torch-2.2.2
# python(81438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting torchtext==0.17.2
#   Downloading torchtext-0.17.2-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.4 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: torch==2.2.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torchtext==0.17.2) (2.2.2)
# Requirement already satisfied: requests in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torchtext==0.17.2) (2.32.5)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torchtext==0.17.2) (1.26.4)
# Requirement already satisfied: tqdm in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torchtext==0.17.2) (4.67.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.17.0)
# Requirement already satisfied: fsspec in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch==2.2.2->torchtext==0.17.2) (2023.10.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.1.5)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.4.2)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch==2.2.2->torchtext==0.17.2) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch==2.2.2->torchtext==0.17.2) (4.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->torchtext==0.17.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->torchtext==0.17.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->torchtext==0.17.2) (2025.6.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->torchtext==0.17.2) (2.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from jinja2->torch==2.2.2->torchtext==0.17.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from sympy->torch==2.2.2->torchtext==0.17.2) (1.3.0)
# Installing collected packages: torchtext
# Successfully installed torchtext-0.17.2
# Collecting portalocker==2.8.2
#   Using cached portalocker-2.8.2-py3-none-any.whl (17 kB)
# Installing collected packages: portalocker
#   Attempting uninstall: portalocker
#     Found existing installation: portalocker 3.2.0
#     Uninstalling portalocker-3.2.0:
#       Successfully uninstalled portalocker-3.2.0
# Successfully installed portalocker-2.8.2
# Collecting torchdata==0.7.1
#   Downloading torchdata-0.7.1-cp310-cp310-macosx_11_0_arm64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 1.1 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: urllib3>=1.25 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torchdata==0.7.1) (2.5.0)
# Requirement already satisfied: torch>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torchdata==0.7.1) (2.2.2)
# Requirement already satisfied: requests in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torchdata==0.7.1) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch>=2->torchdata==0.7.1) (4.14.1)
# Requirement already satisfied: fsspec in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch>=2->torchdata==0.7.1) (2023.10.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch>=2->torchdata==0.7.1) (3.4.2)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch>=2->torchdata==0.7.1) (1.13.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch>=2->torchdata==0.7.1) (3.1.5)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch>=2->torchdata==0.7.1) (3.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->torchdata==0.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->torchdata==0.7.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->torchdata==0.7.1) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from jinja2->torch>=2->torchdata==0.7.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from sympy->torch>=2->torchdata==0.7.1) (1.3.0)
# Installing collected packages: torchdata
# Successfully installed torchdata-0.7.1
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib==3.9.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (3.9.0)
# Requirement already satisfied: scikit-learn==1.5.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (11.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (4.60.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (3.2.5)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from matplotlib==3.9.0) (0.12.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from scikit-learn==1.5.0) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from scikit-learn==1.5.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from scikit-learn==1.5.0) (1.5.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.9.0) (1.16.0)
# Collecting numpy==1.26.0
#   Using cached numpy-1.26.0-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed numpy-1.26.0
# Requirement already satisfied: huggingface_hub in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface_hub) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface_hub) (2023.10.0)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from huggingface_hub) (3.17.0)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from huggingface_hub) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface_hub) (4.14.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (2025.6.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: datasets in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (4.4.2)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (1.26.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: fsspec[http]<=2025.10.0,>=2023.1.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (2023.10.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (23.0)
# Requirement already satisfied: xxhash in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: requests>=2.32.2 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.7)
# Requirement already satisfied: certifi in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2025.6.15)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.8.0)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.14.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.1.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: transformers in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (4.42.1)
# Requirement already satisfied: numpy<2.0,>=1.17 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (1.26.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: requests in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tqdm>=4.27 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.14.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Collecting trl==0.11
#   Downloading trl-0.11.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting peft==0.11.1
#   Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 5.4 MB/s eta 0:00:00a 0:00:01
# ERROR: Could not find a version that satisfies the requirement bitsandbytes==0.43.1 (from versions: 0.31.8, 0.32.0, 0.32.1, 0.32.2, 0.32.3, 0.33.0, 0.33.1, 0.34.0, 0.35.0, 0.35.1, 0.35.2, 0.35.3, 0.35.4, 0.36.0, 0.36.0.post1, 0.36.0.post2, 0.37.0, 0.37.1, 0.37.2, 0.38.0, 0.38.0.post1, 0.38.0.post2, 0.38.1, 0.39.0, 0.39.1, 0.40.0, 0.40.0.post1, 0.40.0.post2, 0.40.0.post3, 0.40.0.post4, 0.40.1, 0.40.1.post1, 0.40.2, 0.41.0, 0.41.1, 0.41.2, 0.41.2.post1, 0.41.2.post2, 0.41.3, 0.41.3.post1, 0.41.3.post2, 0.42.0, 0.49.0)
# ERROR: No matching distribution found for bitsandbytes==0.43.1

# %%
# !pip install --user datasets
# Out:
# Requirement already satisfied: datasets in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (4.4.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (1.26.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: xxhash in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: httpx<1.0.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: requests>=2.32.2 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: fsspec[http]<=2025.10.0,>=2023.1.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from datasets) (2023.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: certifi in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2025.6.15)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.7)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.1.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)

# %%
# !pip install -U bitsandbytes --no-deps
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.0-py3-none-macosx_14_0_arm64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 434.5 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.0

# %% [markdown]
# ### Import required libraries
#
# The following code imports required libraries.

# %%
# !pip install --upgrade torch
# Out:
# Requirement already satisfied: torch in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (2.2.2)
# Collecting torch
#   Downloading torch-2.9.1-cp310-none-macosx_11_0_arm64.whl (74.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 2.2 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch) (4.14.1)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 4.7 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: fsspec>=0.8.5 in /Users/zdravkobozhkov/.local/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: networkx>=2.5.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from torch) (3.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.9.1 which is incompatible.
# torchtext 0.17.2 requires torch==2.2.2, but you have torch 2.9.1 which is incompatible.
# Successfully installed sympy-1.14.0 torch-2.9.1

# %%
import torch
import matplotlib.pyplot as plt
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

import json

import numpy as np

from datasets import load_dataset, load_metric

from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments, BitsAndBytesConfig

from peft import LoraConfig, get_peft_model, TaskType, replace_lora_weights_loftq, prepare_model_for_kbit_training
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       2 import matplotlib.pyplot as plt
#       3 # You can also use this section to suppress warnings generated by your code:
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# Let's check whether a compatible GPU is available:

# %%
# Move the model to the appropriate device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Define helper functions
#
# Here are some helper functions. We will use these later to save and load from JSON:

# %%
def save_to_json(data, file_path):
    """
    Save a dictionary to a JSON file.

    Args:
        data (dict): The dictionary to save.
        file_path (str): The path to the JSON file.
    """
    with open(file_path, 'w') as json_file:
        json.dump(data, json_file, indent=4)
    print(f"Data successfully saved to {file_path}")
    
    
def load_from_json(file_path):
    """
    Load data from a JSON file.

    Args:
        file_path (str): The path to the JSON file.

    Returns:
        dict: The data loaded from the JSON file.
    """
    with open(file_path, 'r') as json_file:
        data = json.load(json_file)
    return data

# %% [markdown]
# # IMDB dataset
#
# The IMDB dataset is a large movie review dataset, consisting of 50,000 movie reviews for training and 25,000 movie reviews for testing. The reviews are labeled as either positive or negative, and each review is a variable-length sequence of words. The IMDB dataset is a popular benchmark for text classification tasks, and it has been used to train a variety of natural language processing models. The following line loads the IMDB dataset:

# %%
imdb = load_dataset("imdb")

# %% [markdown]
# Let's display the structure of the IMDB dataset:

# %%
# Display the structure of the dataset
print("Dataset structure:")
print(imdb)

# %% [markdown]
# The following displays the available splits in the dataset (train, test, unsupervised)

# %%
imdb.keys()

# %% [markdown]
# Let's explore and print a sample from the training set:

# %%
# Explore and print a sample from the training set
print("\nSample from the training set:")
print(imdb['train'][0])

# %% [markdown]
# The followiong displays the unique class labels in the dataset. For the IMDB dataset, the labels are integers representing sentiment, where 0 stands for “negative” and 1 stands for “positive”. Here’s how you can extract this information:

# %%
train_labels = imdb['train']['label']
unique_labels = set(train_labels)
print("\nUnique labels in the dataset (class information):")
print(unique_labels)

# %% [markdown]
# The following dictionary maps class values to class names:

# %%
class_names = {0: "negative", 1: "positive"}
class_names

# %% [markdown]
# Since the IMDB dataset is quite large, we’ll create smaller subsets to facilitate quicker training and testing.
#
# In this notebook, we simulate training and testing using the `small_` datasets due to time constraints. However, it's important to recognize that these smaller datasets are insufficient for proper fine-tuning of the DistilBERT model. For more accurate results, a larger subsample, such as the `medium_train_dataset`, would be necessary.
#
# Consequently, all results presented here pertain to models trained with the `medium_train_dataset` and evaluated on the test set from `medium_test_dataset`. However, the notebook, as is, does NOT train models on these datasets; rather, it trains models using the `small_` datasets, as training on the `medium_` datasets would be too time-consuming.

# %%
small_train_dataset = imdb["train"].shuffle(seed=42).select([i for i in list(range(50))])
small_test_dataset = imdb["test"].shuffle(seed=42).select([i for i in list(range(50))])
medium_train_dataset = imdb["train"].shuffle(seed=42).select([i for i in list(range(3000))])
medium_test_dataset = imdb["test"].shuffle(seed=42).select([i for i in list(range(300))])

# %% [markdown]
# # Tokenizer
#
# The following loads the DistilBERT tokenizer:

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %% [markdown]
# The tokenizer provides tokenized input IDs and an attention mask for a given input text:

# %%
my_tokens=tokenizer(imdb['train'][0]['text'])

# Print the tokenized input IDs
print("Input IDs:", my_tokens['input_ids'])

# Print the attention mask
print("Attention Mask:", my_tokens['attention_mask'])

# If token_type_ids is present, print it
if 'token_type_ids' in my_tokens:
    print("Token Type IDs:", my_tokens['token_type_ids'])

# %% [markdown]
# The following preprocessing function tokenizes a text input. We apply this function to all texts in our datasets using the `.map()` method:

# %%
def preprocess_function(examples):
    return tokenizer(examples["text"], padding=True, truncation=True, max_length=512)

small_tokenized_train = small_train_dataset.map(preprocess_function, batched=True)
small_tokenized_test = small_test_dataset.map(preprocess_function, batched=True)
medium_tokenized_train = medium_train_dataset.map(preprocess_function, batched=True)
medium_tokenized_test = medium_test_dataset.map(preprocess_function, batched=True)

# %% [markdown]
# Run the following to see what a sample from the tokenized dataset looks like. Note that this dataset is identical to the original, with just the token indices and attention mask appended.

# %%
print(small_tokenized_train[49])

# %% [markdown]
# The following defines the `compute_metrics` funcion to evaluate model performance using accuracy:

# %%
# !pip install evaluate

import evaluate
def compute_metrics(eval_pred):
   load_accuracy = evaluate.load("accuracy")


   logits, labels = eval_pred
   predictions = np.argmax(logits, axis=-1)
   accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]

   return {"accuracy": accuracy}

# %% [markdown]
# ---

# %% [markdown]
# # Configure BitsAndBytes

# %% [markdown]
# The following code creates a `BitsAndBytes` config object where we define the quantization parameters. Every line in that config is commented to inform you of its function:

# %%
config_bnb = BitsAndBytesConfig(
    load_in_4bit=True, # quantize the model to 4-bits when you load it
    bnb_4bit_quant_type="nf4", # use a special 4-bit data type for weights initialized from a normal distribution
    bnb_4bit_use_double_quant=True, # nested quantization scheme to quantize the already quantized weights
    bnb_4bit_compute_dtype=torch.bfloat16, # use bfloat16 for faster computation
    llm_int8_skip_modules=["classifier", "pre_classifier"] #  Don't convert the "classifier" and "pre_classifier" layers to 8-bit
)

# %% [markdown]
# # Load a quantized version of a pretrained model

# %% [markdown]
# The following code creates two lists. The first list (`id2label`) maps ids to text labels for the two classes in this problem, and the second list (`label2id`) swaps the keys and the values to map the text labels to the ids:

# %%
id2label = {0: "NEGATIVE", 1: "POSITIVE"}
label2id = dict((v,k) for k,v in id2label.items())

# %% [markdown]
# The following instantiates an `AutoModelForSequenceClassification` from a pre-trained `distilbert-base-uncased` model using the `BitsAndBytesConfig` defined above and the id to label and label to id mappings. The `quantization_config` parameter in particular indicates that a quantized version of the model should be loaded, with the quantization settings contained in the config object passed to `quantization_config`

# %%
model_qlora = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased",
                                                                 id2label=id2label,
                                                                 label2id=label2id,
                                                                 num_labels=2,
                                                                 quantization_config=config_bnb
                                                                )

# %%
import torch
print(torch.cuda.is_available())  # Should return True if CUDA is available
print(torch.cuda.device_count())

# %% [markdown]
# `model_qlora` is now a quantized instance of the model, but the model is not ready for quantized training just yet. This is accomplished by passing the model through the `prepare_model_for_kbit_training()` function:

# %%
model_qlora = prepare_model_for_kbit_training(model_qlora)

# %% [markdown]
# Despite its name, `model_qlora` is not a LoRA or QLoRA object yet, but a quantized instance of a pre-trained `distilbert-base-uncased` model that has been made ready for quantized training. To allow this model to be fine-tuned using QLoRA, we must convert the linear layers into LoRA layers. This is done analogously to the way LoRA is applied to a non-quantized model:

# %%
lora_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,  # Specify the task type as sequence classification
    r=8,  # Rank of the low-rank matrices
    lora_alpha=16,  # Scaling factor
    lora_dropout=0.1,  # Dropout rate  
    target_modules=['q_lin','k_lin','v_lin'] # which modules
)

peft_model_qlora = get_peft_model(model_qlora, lora_config)

# %% [markdown]
# `peft_model_qlora` is now a QLoRA model which we can go ahead and train. However, before doing so, we will perform one other optimization: we will reinitialize the LoRA weights using LoftQ, which has been shown to improve performance when training quantized models. You can find information about LoftQ [here](https://arxiv.org/abs/2310.08659).

# %%
replace_lora_weights_loftq(peft_model_qlora)

# %% [markdown]
# Let's print out the model summary:

# %%
print(peft_model_qlora)

# %% [markdown]
# As you can see, the `distilbert-base-uncased` model adapted for QLoRA fine-tuning has a similar structure to the non-quantized LoRA model derived from `distilbert-base-uncased`. The key difference in the structure's summary is the conversion of some of the `Linear` layers into `Linear4bit` layers, which are 4-bit linear layers that use blockwise k-bit quantization under the hood.

# %%
peft_model_qlora.print_trainable_parameters()

# %% [markdown]
# As can be seen above, fine-tuning the `distilbert-base-uncased` model using QLoRA with a rank of 8 results in just 1.2% of the resulting parameters being trainable.

# %% [markdown]
# # Train

# %% [markdown]
# Fine-tuning the QLoRA model from this point on is identical to fine-tuning a LoRA model. First, define the training arguments:

# %%
training_args = TrainingArguments(
    output_dir="./results_qlora",
    num_train_epochs=10,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    learning_rate=2e-5,
    evaluation_strategy="epoch",
    weight_decay=0.01
)

# %% [markdown]
# Then, train the model using `Trainer`:

# %%
trainer_qlora = Trainer(
    model=peft_model_qlora,
    args=training_args,
    train_dataset=medium_tokenized_train,
    eval_dataset=medium_tokenized_test,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics)


trainer_qlora.train()

# %% [markdown]
# Training on a V100 GPU results in the following table:
#
# ![Training table](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/r4Xq0iBAkaIC1UNg7S5w0Q/Screenshot%202024-07-08%20at%2010-48-20%E2%80%AFAM.png)

# %% [markdown]
# As you can see, training the 1.2% of parameters on a V100 takes just under 10 minutes and results in a validation accuracy of 84.3%. This is comparable to the accuracy we can expect to get from LoRA.

# %% [markdown]
# You can save a trained QLoRA model using the following:

# %%
trainer_qlora.save_model("./qlora_final_model")

# %% [markdown]
# # Results

# %% [markdown]
# To analyze how training progresses with each epoch, you can also extract the log history:

# %%
log_history_qlora = trainer_qlora.state.log_history

# %% [markdown]
# This log history can be used to calculate our accuracy metric using the following `lambda` function:

# %%
get_metric_qlora = lambda metric, log_history_qlora: [log[metric] for log in log_history_qlora if metric in log]

# %% [markdown]
# And this function can, in turn, be used to plot what happens to the evaluation loss and accuracy during training:

# %%
eval_accuracy_qlora=get_metric_qlora('eval_accuracy',log_history_qlora)
eval_loss_qlora=get_metric_qlora('eval_loss',log_history_qlora)
plt.plot(eval_accuracy_qlora,label='eval_accuracy')
plt.plot(eval_loss_qlora,label='eval_loss')
plt.xlabel("epoch")
plt.legend()

# %% [markdown]
# The above code results in the following plot:
#
# ![qlora_training_plot](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/wzMMj73IuM6fKmPZtKtQNA/qlora-training-plot.png)

# %% [markdown]
# The above code indicates that, in this particular instance, the bulk of the benefits from fine-tuning were gained within the first 3 epochs.

# %% [markdown]
# ---

# %% [markdown]
# ## Congratulations! You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# [Wojciech "Victor" Fulmyk](https://www.linkedin.com/in/wfulmyk) is a Data Scientist and a PhD Candidate in Economics at the University of Calgary.

# %% [markdown]
# [Fateme Akbari](https://www.linkedin.com/in/fatemeakbari/) is a Ph.D. candidate in Information Systems at McMaster University with demonstrated research experience in Machine Learning and NLP.

# %% [markdown]
# [Joseph Santarcangelo](https://author.skills.network/instructors/joseph_santarcangelo) has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## References
#
# [Finetuning with LoRA -- A Hands-On Example](https://lightning.ai/lightning-ai/studios/code-lora-from-scratch)
#
# [QLORA: Efficient Finetuning of Quantized LLMs](https://arxiv.org/pdf/2305.14314)
#
# [Making LLMs even more accessible with bitsandbytes, 4-bit quantization and QLoRA](https://huggingface.co/blog/4bit-transformers-bitsandbytes)

# %% [markdown]
# <!-- ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-07-09|0.99|Victor|Lab written|
# --!>

# %% [markdown]
# Copyright © 2024 IBM Corporation. All rights reserved.
